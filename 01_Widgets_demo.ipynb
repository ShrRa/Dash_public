# %%
import pandas as pd
import os
import datashader, hvplot, holoviews as hv 
hv.extension('bokeh', 'matplotlib')
# Out:
# /home/alex/miniconda3/envs/py3.12/lib/python3.12/site-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="ad2c772a-f62c-47e3-8b08-53637946a1b6" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"4df0a2e4-d17e-4202-8377-46c42abb1134":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"c8cd692e1308492c93a68068bba5ea84","client_comm_id":"f61383ce5ff34eb0b1617daaed4826b8"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"4df0a2e4-d17e-4202-8377-46c42abb1134","roots":{"p1002":"ad2c772a-f62c-47e3-8b08-53637946a1b6"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %% [markdown]
# ### Open datasets

# %%
dir_data = 'data'
# Import Kepler LC for a single RR Lyr object
cat_kepler = pd.read_csv(os.path.join(dir_data,'kepler_RRLyr.csv')) 
# Import LSST multi-band LCs for a number of RR Lyr candidates
cat_lsst = pd.read_pickle(os.path.join(dir_data,'lsst_RRLyr.pkl'))

# %%
bands_lsst = 'ugrizy'
colors = ['#cc78a7','#0072b2','#009e73',
          '#f0e442','#e69f00','#d55e00']

# %% [markdown]
# #### Inspect the data

# %%
cat_kepler.head()
# Out:
#          time        flux   flux_err  quality  timecorr  centroid_col  \
# 0  131.512404  10180609.0  78.926155      128  0.001410    653.372470
# 1  131.532839  10013518.0  78.233770      128  0.001411    653.372292
# 2  131.553273   9852474.0  77.673160      128  0.001412    653.372167
# 3  131.573707   9722936.0  77.109710      128  0.001413    653.371408
# 4  131.594142   9717073.0  77.103550        0  0.001414    653.372167
#
#    centroid_row  cadenceno    sap_flux  sap_flux_err  ...  psf_centr1  \
# 0     51.053028       1105  10129629.0     79.186980  ...         NaN
# 1     51.053872       1106   9949931.0     78.459984  ...         NaN
# 2     51.044559       1107   9783633.0     77.827200  ...         NaN
# 3     51.045081       1108   9651452.0     77.313590  ...         NaN
# 4     51.052828       1109   9646289.0     77.262634  ...         NaN
#
#    psf_centr1_err  psf_centr2  psf_centr2_err  mom_centr1  mom_centr1_err  \
# 0             NaN         NaN             NaN  653.372470        0.000006
# 1             NaN         NaN             NaN  653.372292        0.000006
# 2             NaN         NaN             NaN  653.372167        0.000006
# 3             NaN         NaN             NaN  653.371408        0.000006
# 4             NaN         NaN             NaN  653.372167        0.000006
#
#    mom_centr2  mom_centr2_err  pos_corr1  pos_corr2
# 0   51.053028        0.000063   0.011782  -0.010195
# 1   51.053872        0.000062   0.011726  -0.010246
# 2   51.044559        0.000062   0.011575  -0.010089
# 3   51.045081        0.000062   0.011366  -0.009939
# 4   51.052828        0.000062   0.011526  -0.010702
#
# [5 rows x 25 columns]

# %%
cat_kepler.columns
# Out:
# Index(['time', 'flux', 'flux_err', 'quality', 'timecorr', 'centroid_col',
#        'centroid_row', 'cadenceno', 'sap_flux', 'sap_flux_err', 'sap_bkg',
#        'sap_bkg_err', 'pdcsap_flux', 'pdcsap_flux_err', 'sap_quality',
#        'psf_centr1', 'psf_centr1_err', 'psf_centr2', 'psf_centr2_err',
#        'mom_centr1', 'mom_centr1_err', 'mom_centr2', 'mom_centr2_err',
#        'pos_corr1', 'pos_corr2'],
#       dtype='object')

# %%
cat_lsst.head()
# Out:
#   band  ccdVisitId   coord_ra  coord_dec             objectId      psfFlux  \
# 0    y  1032263018  62.462569  -44.11336  1251384969897480052  -515.183603
# 1    y  1033987172  62.462569  -44.11336  1251384969897480052  3151.738459
# 2    u   675163080  62.462569  -44.11336  1251384969897480052   183.449123
# 3    y   443055067  62.462569  -44.11336  1251384969897480052  -704.848327
# 4    u   466722002  62.462569  -44.11336  1251384969897480052   382.472233
#
#     psfFluxErr     psfMag  ccdVisitId2 band2   expMidptMJD  zeroPoint
# 0  1697.218490        NaN   1032263018     y  61100.069706  30.602301
# 1  1686.955775  22.653625   1033987172     y  61102.068464  30.606100
# 2   209.242045  25.741211    675163080     u  60582.247144  30.469101
# 3  1624.400086        NaN    443055067     y  60215.203585  30.612801
# 4   278.926670  24.943500    466722002     u  60261.078221  30.461201

# %%
cat_lsst.columns
# Out:
# Index(['band', 'ccdVisitId', 'coord_ra', 'coord_dec', 'objectId', 'psfFlux',
#        'psfFluxErr', 'psfMag', 'ccdVisitId2', 'band2', 'expMidptMJD',
#        'zeroPoint'],
#       dtype='object')

# %% [markdown]
# ### LC widgets
# Instead of making multiple plots with different display parameters, we can use widgets to create interactive plots with multiple options.

# %%
import panel as pn
import hvplot.pandas
pn.extension(throttled=True)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='4021c118-2389-4846-bc47-90ab2a75b45d'>
#   <div id="d0dfc872-abd3-4a95-9fb7-1c8d5a429190" data-root-id="4021c118-2389-4846-bc47-90ab2a75b45d" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"1ff4f23b-17b6-4b94-ab27-73840a0d4007":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"4021c118-2389-4846-bc47-90ab2a75b45d"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"400419f4-6e27-400b-a45f-93ebf128cc0d","attributes":{"plot_id":"4021c118-2389-4846-bc47-90ab2a75b45d","comm_id":"b6d0a0100b6242108057e8cb5e7b54df","client_comm_id":"b91e01eb6518447ba3086520932fded0"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"1ff4f23b-17b6-4b94-ab27-73840a0d4007","roots":{"4021c118-2389-4846-bc47-90ab2a75b45d":"d0dfc872-abd3-4a95-9fb7-1c8d5a429190"},"root_ids":["4021c118-2389-4846-bc47-90ab2a75b45d"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Create a slider for selecting maximum magnitude
mag_slider = pn.widgets.FloatSlider(name='Max magnitude', start=15, end=32, 
                                    value=22, step=0.05)

# %%
b = 'r'
color = '#009e73'
mask = cat_lsst['band'] == b
mag_slider
rdf = pn.rx(cat_lsst[mask])
rdf[rdf['psfMag'] < mag_slider].head()
# Out:
# <div id='5a6da855-74d4-4185-a298-8d8abc5a54df'>
#   <div id="d4943d53-ba62-4dd5-aff8-3dcc7dd18b90" data-root-id="5a6da855-74d4-4185-a298-8d8abc5a54df" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"62a728c6-055b-4300-ba06-8ce79639e543":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"5a6da855-74d4-4185-a298-8d8abc5a54df","attributes":{"name":"Row01541","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"44f19fd4-ab1c-4665-a70e-8868f4ab0309","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"22eb4dd4-31d2-43e5-9ead-12bf60c96a5c","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"4dd24cc7-23d9-4d6d-a954-2fa2ee542a00","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"3d701c97-6ec7-464b-8cc8-6e7bd6bb36d5","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Row","id":"4910067f-8b76-4c72-8cac-10dd1198f71e","attributes":{"name":"Row01550","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"44f19fd4-ab1c-4665-a70e-8868f4ab0309"},{"id":"22eb4dd4-31d2-43e5-9ead-12bf60c96a5c"},{"id":"4dd24cc7-23d9-4d6d-a954-2fa2ee542a00"},{"id":"3d701c97-6ec7-464b-8cc8-6e7bd6bb36d5"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"563f8e14-ea2c-42da-9980-bc72b3801759","attributes":{"name":"WidgetBox01549","css_classes":["panel-widget-box"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"44f19fd4-ab1c-4665-a70e-8868f4ab0309"},{"type":"object","name":"ImportedStyleSheet","id":"ea9fa057-9447-47d9-9a19-1f70f0401eb9","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/widgetbox.css"}},{"id":"22eb4dd4-31d2-43e5-9ead-12bf60c96a5c"},{"id":"4dd24cc7-23d9-4d6d-a954-2fa2ee542a00"},{"id":"3d701c97-6ec7-464b-8cc8-6e7bd6bb36d5"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"31cd59ab-c842-46d9-a67d-01ef74e07a23","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"44f19fd4-ab1c-4665-a70e-8868f4ab0309"},{"id":"4dd24cc7-23d9-4d6d-a954-2fa2ee542a00"},{"id":"3d701c97-6ec7-464b-8cc8-6e7bd6bb36d5"}],"margin":[5,10],"align":"start","title":"Max magnitude","start":15,"end":32,"value":22,"step":0.05}}]}},{"type":"object","name":"panel.models.layout.Column","id":"976de548-5402-477c-87b6-62d2c66935b6","attributes":{"name":"Column01546","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"44f19fd4-ab1c-4665-a70e-8868f4ab0309"},{"id":"22eb4dd4-31d2-43e5-9ead-12bf60c96a5c"},{"id":"4dd24cc7-23d9-4d6d-a954-2fa2ee542a00"},{"id":"3d701c97-6ec7-464b-8cc8-6e7bd6bb36d5"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"ea1ac573-337b-4bda-b188-7300e50317c0","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"44f19fd4-ab1c-4665-a70e-8868f4ab0309"},{"type":"object","name":"ImportedStyleSheet","id":"8d1ad06b-9a91-4047-a7af-32d56d5a6466","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/ ...

# %%
rdf[rdf['psfMag'] < mag_slider].hvplot.scatter(x='expMidptMJD',y='psfMag',title=b, color=color).opts(width=500,height=300)
# Out:
# <div id='d9ecc1f2-2b48-4887-85e0-25c6ee12a9a2'>
#   <div id="ee4f6251-c12a-433e-ad8d-b1629f0a162b" data-root-id="d9ecc1f2-2b48-4887-85e0-25c6ee12a9a2" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"db7ec56d-6600-45be-83b5-797f97476e66":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"d9ecc1f2-2b48-4887-85e0-25c6ee12a9a2","attributes":{"name":"Row01650","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"f08954c4-d2e8-420a-9780-f4233a4a5bfd","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"cd5b37dc-738d-4032-b31c-28261b30c169","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"134c8de7-1537-46f2-bb27-b40d53e7ec34","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"668264ff-36ac-40b0-85a5-173657a7d08c","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Row","id":"aadd32fd-79ce-41e2-8c5a-87d150c7af4f","attributes":{"name":"Row01685","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"f08954c4-d2e8-420a-9780-f4233a4a5bfd"},{"id":"cd5b37dc-738d-4032-b31c-28261b30c169"},{"id":"134c8de7-1537-46f2-bb27-b40d53e7ec34"},{"id":"668264ff-36ac-40b0-85a5-173657a7d08c"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"ce1520a7-d8ad-4e10-b8a1-de4cd8b6136a","attributes":{"name":"WidgetBox01684","css_classes":["panel-widget-box"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"f08954c4-d2e8-420a-9780-f4233a4a5bfd"},{"type":"object","name":"ImportedStyleSheet","id":"f58252bd-579d-41f4-8d90-9e85f3901195","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/widgetbox.css"}},{"id":"cd5b37dc-738d-4032-b31c-28261b30c169"},{"id":"134c8de7-1537-46f2-bb27-b40d53e7ec34"},{"id":"668264ff-36ac-40b0-85a5-173657a7d08c"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"46d351ea-ec6a-4bba-9870-2071e158820e","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"f08954c4-d2e8-420a-9780-f4233a4a5bfd"},{"id":"134c8de7-1537-46f2-bb27-b40d53e7ec34"},{"id":"668264ff-36ac-40b0-85a5-173657a7d08c"}],"margin":[5,10],"align":"start","title":"Max magnitude","start":15,"end":32,"value":22,"step":0.05}}]}},{"type":"object","name":"panel.models.layout.Column","id":"939f8edf-26b9-431d-9b28-a35d80c8dde3","attributes":{"name":"Column01655","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"f08954c4-d2e8-420a-9780-f4233a4a5bfd"},{"id":"cd5b37dc-738d-4032-b31c-28261b30c169"},{"id":"134c8de7-1537-46f2-bb27-b40d53e7ec34"},{"id":"668264ff-36ac-40b0-85a5-173657a7d08c"}],"margin":0,"sizing_mode":"fixed","align":"start","children":[{"type":"object","name":"Figure","id":"6929fe60-da07-470e-b31d-7a2e541688e1","attributes":{"name":"ParamFunction01651","width":500,"height":300,"margin":[5,10],"sizing_mode":"fixed","align":"start","x_range":{"type":"object","name":"Range1d","id":"a44c4931-0472-400b-8044-ed762bf5eb07","attributes":{"tags":[[["expMidptMJD",null]],[]],"start":59527.7840383,"end":61511.3902951,"reset_start":59527.7840383,"reset_end":61511.3902951}},"y_range":{"type":"object","name":"Ran ...

# %%
# Create a selector for picking photometric band
band_selector = pn.widgets.Select(name='Band', options=['u','g','r','i','z','i'])

# %%
rdf = pn.rx(cat_lsst)
rdf[rdf['band'] == band_selector].head()
# Out:
# <div id='2afd7eb3-f406-43f0-99e5-e8060aad8769'>
#   <div id="c4755343-4116-4a24-87b6-5daa8f799256" data-root-id="2afd7eb3-f406-43f0-99e5-e8060aad8769" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"29e59175-fd0e-476c-9076-bbe28535afea":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"2afd7eb3-f406-43f0-99e5-e8060aad8769","attributes":{"name":"Row01712","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"79512bf4-2504-431c-b01a-175c4b8ed514","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"7cb0a225-9a9b-4cd4-aeae-d2c5d96ec59d","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"fb411b01-97ed-49d1-a533-03486de0253f","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"189fd724-326d-4ac2-b032-3c69ad9ee825","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Row","id":"98c61c38-2b3d-4a6c-99f4-4e972b062ad6","attributes":{"name":"Row01721","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"79512bf4-2504-431c-b01a-175c4b8ed514"},{"id":"7cb0a225-9a9b-4cd4-aeae-d2c5d96ec59d"},{"id":"fb411b01-97ed-49d1-a533-03486de0253f"},{"id":"189fd724-326d-4ac2-b032-3c69ad9ee825"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"36a6c369-2adf-429c-a989-a0cc86db2116","attributes":{"name":"WidgetBox01720","css_classes":["panel-widget-box"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"79512bf4-2504-431c-b01a-175c4b8ed514"},{"type":"object","name":"ImportedStyleSheet","id":"9fb9e13a-44df-4c3c-9154-4d22861fff38","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/widgetbox.css"}},{"id":"7cb0a225-9a9b-4cd4-aeae-d2c5d96ec59d"},{"id":"fb411b01-97ed-49d1-a533-03486de0253f"},{"id":"189fd724-326d-4ac2-b032-3c69ad9ee825"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.widgets.CustomSelect","id":"0786d855-3a08-46c6-bb77-0b4b1924b460","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"79512bf4-2504-431c-b01a-175c4b8ed514"},{"type":"object","name":"ImportedStyleSheet","id":"bccebc12-772f-482c-afef-e434479a2001","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/select.css"}},{"id":"fb411b01-97ed-49d1-a533-03486de0253f"},{"id":"189fd724-326d-4ac2-b032-3c69ad9ee825"}],"width":300,"min_width":300,"margin":[5,10],"align":"start","title":"Band","options":["u","g","r","i","z","i"],"value":"u"}}]}},{"type":"object","name":"panel.models.layout.Column","id":"5e0b47bf-1f18-4a35-aff1-cc3d5e7b02c1","attributes":{"name":"Column01717","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"79512bf4-2504-431c-b01a-175c4b8ed514"},{"id":"7cb0a225-9a9b-4cd4-aeae-d2c5d96ec59d"},{"id":"fb411b01-97ed-49d1-a533-03486de0253f"},{"id":"189fd724-326d-4ac2-b032-3c69ad9ee825"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"b5e53024-4774-45c1-8400-31ac1d2c20e3","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto ...

# %%
# Create a selector for choosing psdMags or psfFluxes
units_selector = pn.widgets.Select(name='Flux/Mag', options=['psfFlux','psfMag'])

# %%
data = rdf[(rdf['psfMag'] < mag_slider) & (rdf['band'] == band_selector)]
plot = data.hvplot.scatter(x='expMidptMJD',y=units_selector, title=band_selector, color=color).opts(width=500,height=300)
plot
# Out:
# <div id='d06cb423-9cf1-4b04-89e5-630a653fab7c'>
#   <div id="a97cc97f-577b-4b7c-afb9-fea1756de07a" data-root-id="d06cb423-9cf1-4b04-89e5-630a653fab7c" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"0cd61efc-81fd-4ea0-968b-b2b1c021244b":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"d06cb423-9cf1-4b04-89e5-630a653fab7c","attributes":{"name":"Row01822","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"353befdd-08a0-45ce-9399-914f1f0b6613","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"3805502e-74d9-4667-8aa8-2ecb7dcc709a","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"8641b2bb-a858-4c9a-a422-145df4e1b579","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"9af6c4bb-71f5-466a-8305-c31ab0546d5f","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Row","id":"79682237-5f89-42f4-b0ac-c15a46200376","attributes":{"name":"Row01857","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"353befdd-08a0-45ce-9399-914f1f0b6613"},{"id":"3805502e-74d9-4667-8aa8-2ecb7dcc709a"},{"id":"8641b2bb-a858-4c9a-a422-145df4e1b579"},{"id":"9af6c4bb-71f5-466a-8305-c31ab0546d5f"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"2533b5bb-319f-49a8-a881-b24cd9c5be6e","attributes":{"name":"WidgetBox01856","css_classes":["panel-widget-box"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"353befdd-08a0-45ce-9399-914f1f0b6613"},{"type":"object","name":"ImportedStyleSheet","id":"e4127aa3-4e0a-41b7-83a2-390ee2905291","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/widgetbox.css"}},{"id":"3805502e-74d9-4667-8aa8-2ecb7dcc709a"},{"id":"8641b2bb-a858-4c9a-a422-145df4e1b579"},{"id":"9af6c4bb-71f5-466a-8305-c31ab0546d5f"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"79cc3767-88bc-4eb5-a9fb-20584d0cf81b","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"353befdd-08a0-45ce-9399-914f1f0b6613"},{"id":"8641b2bb-a858-4c9a-a422-145df4e1b579"},{"id":"9af6c4bb-71f5-466a-8305-c31ab0546d5f"}],"margin":[5,10],"align":"start","title":"Max magnitude","start":15,"end":32,"value":22,"step":0.05}},{"type":"object","name":"panel.models.widgets.CustomSelect","id":"81f0af05-04d4-4012-b291-15c91565cccb","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"353befdd-08a0-45ce-9399-914f1f0b6613"},{"type":"object","name":"ImportedStyleSheet","id":"f89fd548-4aec-4f1d-a7a6-410c55c775bd","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/select.css"}},{"id":"8641b2bb-a858-4c9a-a422-145df4e1b579"},{"id":"9af6c4bb-71f5-466a-8305-c31ab0546d5f"}],"width":300,"min_width":300,"margin":[5,10],"align":"start","title":"Band","options":["u","g","r","i","z","i"],"value":"u"}},{"type":"object","name":"panel.models.widgets.CustomSelect","id":"572829a5-aa78-4fe9-a3f9-ddb1ab48daa9","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400p ...
