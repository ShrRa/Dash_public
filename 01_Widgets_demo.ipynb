# %%
import pandas as pd
import os
import datashader, hvplot, holoviews as hv 
hv.extension('bokeh', 'matplotlib')
# Out:
# /home/alex/miniconda3/envs/py3.12/lib/python3.12/site-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1002'>
#   <div id="b43c20f6-86d4-44b6-934b-49dccb61f1f1" data-root-id="p1002" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"9a19698e-c7bc-4020-8f7c-71bb791c4cc4":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1002"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1003","attributes":{"plot_id":"p1002","comm_id":"e3baa2a671b141d1b29c41ff96dd5be4","client_comm_id":"dd2ffcf3c550465cbb52c5731a771ba1"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"fill","kind":"A ...
#   var render_items = [{"docid":"9a19698e-c7bc-4020-8f7c-71bb791c4cc4","roots":{"p1002":"b43c20f6-86d4-44b6-934b-49dccb61f1f1"},"root_ids":["p1002"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>
# <div class="logo-block">
# <img src='...'
#      style='height:25px; border-radius:12px; display: inline-block; float: left; vertical-align: middle'></img>
#
#
#   <img src='data:image/png;base64,...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
#   <img src='...'
#        style='height:15px; border-radius:12px; display: inline-block; float: left'></img>
#
#
#
# </div>

# %% [markdown]
# ### Open datasets

# %%
dir_data = 'data'
# Import Kepler LC for a single RR Lyr object
cat_kepler = pd.read_csv(os.path.join(dir_data,'kepler_RRLyr.csv')) 
# Import LSST multi-band LCs for a number of RR Lyr candidates
cat_lsst = pd.read_pickle(os.path.join(dir_data,'lsst_RRLyr.pkl'))

# %%
bands_lsst = 'ugrizy'
colors = ['#cc78a7','#0072b2','#009e73',
          '#f0e442','#e69f00','#d55e00']

# %% [markdown]
# #### Inspect the data

# %%
cat_kepler.head()
# Out:
#          time        flux   flux_err  quality  timecorr  centroid_col  \
# 0  131.512404  10180609.0  78.926155      128  0.001410    653.372470
# 1  131.532839  10013518.0  78.233770      128  0.001411    653.372292
# 2  131.553273   9852474.0  77.673160      128  0.001412    653.372167
# 3  131.573707   9722936.0  77.109710      128  0.001413    653.371408
# 4  131.594142   9717073.0  77.103550        0  0.001414    653.372167
#
#    centroid_row  cadenceno    sap_flux  sap_flux_err  ...  psf_centr1  \
# 0     51.053028       1105  10129629.0     79.186980  ...         NaN
# 1     51.053872       1106   9949931.0     78.459984  ...         NaN
# 2     51.044559       1107   9783633.0     77.827200  ...         NaN
# 3     51.045081       1108   9651452.0     77.313590  ...         NaN
# 4     51.052828       1109   9646289.0     77.262634  ...         NaN
#
#    psf_centr1_err  psf_centr2  psf_centr2_err  mom_centr1  mom_centr1_err  \
# 0             NaN         NaN             NaN  653.372470        0.000006
# 1             NaN         NaN             NaN  653.372292        0.000006
# 2             NaN         NaN             NaN  653.372167        0.000006
# 3             NaN         NaN             NaN  653.371408        0.000006
# 4             NaN         NaN             NaN  653.372167        0.000006
#
#    mom_centr2  mom_centr2_err  pos_corr1  pos_corr2
# 0   51.053028        0.000063   0.011782  -0.010195
# 1   51.053872        0.000062   0.011726  -0.010246
# 2   51.044559        0.000062   0.011575  -0.010089
# 3   51.045081        0.000062   0.011366  -0.009939
# 4   51.052828        0.000062   0.011526  -0.010702
#
# [5 rows x 25 columns]

# %%
cat_kepler.columns
# Out:
# Index(['time', 'flux', 'flux_err', 'quality', 'timecorr', 'centroid_col',
#        'centroid_row', 'cadenceno', 'sap_flux', 'sap_flux_err', 'sap_bkg',
#        'sap_bkg_err', 'pdcsap_flux', 'pdcsap_flux_err', 'sap_quality',
#        'psf_centr1', 'psf_centr1_err', 'psf_centr2', 'psf_centr2_err',
#        'mom_centr1', 'mom_centr1_err', 'mom_centr2', 'mom_centr2_err',
#        'pos_corr1', 'pos_corr2'],
#       dtype='object')

# %%
cat_lsst.head()
# Out:
#   band  ccdVisitId   coord_ra  coord_dec             objectId      psfFlux  \
# 0    y  1032263018  62.462569  -44.11336  1251384969897480052  -515.183603
# 1    y  1033987172  62.462569  -44.11336  1251384969897480052  3151.738459
# 2    u   675163080  62.462569  -44.11336  1251384969897480052   183.449123
# 3    y   443055067  62.462569  -44.11336  1251384969897480052  -704.848327
# 4    u   466722002  62.462569  -44.11336  1251384969897480052   382.472233
#
#     psfFluxErr     psfMag  ccdVisitId2 band2   expMidptMJD  zeroPoint
# 0  1697.218490        NaN   1032263018     y  61100.069706  30.602301
# 1  1686.955775  22.653625   1033987172     y  61102.068464  30.606100
# 2   209.242045  25.741211    675163080     u  60582.247144  30.469101
# 3  1624.400086        NaN    443055067     y  60215.203585  30.612801
# 4   278.926670  24.943500    466722002     u  60261.078221  30.461201

# %%
cat_lsst.columns
# Out:
# Index(['band', 'ccdVisitId', 'coord_ra', 'coord_dec', 'objectId', 'psfFlux',
#        'psfFluxErr', 'psfMag', 'ccdVisitId2', 'band2', 'expMidptMJD',
#        'zeroPoint'],
#       dtype='object')

# %%
cat_lsst['objectId'].unique()
# Out:
# array([1251384969897480052, 1251745609711384492, 1252299763571782414,
#        1251604872223041749, 1327638300307004563, 1329353538446317664,
#        1327400805795401837, 1405624461041897445, 1408219308483446461,
#        1569135034231724627, 1567428592185416026, 1566258711813454641,
#        1651589610221899038, 1736726994583845484, 1736208025095542267,
#        1651510445384705236, 1824520799038501324, 1913889104144142393,
#        1910977597353791985, 1998718625250325973, 2003099079575369656,
#        2090857699657944782, 2093945128308742270, 2183075938902767275,
#        2185793931646635508])

# %%
lc = cat_lsst[cat_lsst['objectId'] == cat_lsst['objectId'].unique()[0]]

# %% [markdown]
# ### LC widgets
# Instead of making multiple plots with different display parameters, we can use widgets to create interactive plots with multiple options.

# %%
import panel as pn
import hvplot.pandas
pn.extension(throttled=True)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='37ca4511-72e9-47c4-aaae-70f326bc1702'>
#   <div id="c579a60a-99e3-4ac8-9a4a-822bead45bda" data-root-id="37ca4511-72e9-47c4-aaae-70f326bc1702" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"95ed6f01-9486-44ac-a692-df88c0e5abd0":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"37ca4511-72e9-47c4-aaae-70f326bc1702"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"c219772b-c313-4bb7-aa59-bbfb642d94ce","attributes":{"plot_id":"37ca4511-72e9-47c4-aaae-70f326bc1702","comm_id":"a8c4b5b647ac44f5b38109b69824bf70","client_comm_id":"12493ade92f94e388067f4502f17198d"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"95ed6f01-9486-44ac-a692-df88c0e5abd0","roots":{"37ca4511-72e9-47c4-aaae-70f326bc1702":"c579a60a-99e3-4ac8-9a4a-822bead45bda"},"root_ids":["37ca4511-72e9-47c4-aaae-70f326bc1702"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Create a slider for selecting maximum magnitude
mag_slider = pn.widgets.FloatSlider(name='Max magnitude', start=15, end=32, 
                                    value=22, step=0.05)

# %%
b = 'r'
color = '#009e73'
mask = lc['band'] == b
mag_slider
rdf = pn.rx(lc[mask])
rdf[rdf['psfMag'] < mag_slider].head()
# Out:
# <div id='02fa741f-5d7c-4743-ae40-ab1fcaf193b2'>
#   <div id="f94fd72c-18e6-464d-8d0f-7f0a7c7a4e1c" data-root-id="02fa741f-5d7c-4743-ae40-ab1fcaf193b2" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"e864b486-4423-4306-bd02-2ee194adb88a":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"02fa741f-5d7c-4743-ae40-ab1fcaf193b2","attributes":{"name":"Row01517","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"a1bb4279-8600-4f30-b3d0-2346ed48b609","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"5df9a4f0-8dfd-4707-86f1-bda1c80b859b","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":
attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/select.css"}},{"id":"1bca7df4-b270-4965-a20a-0ea6e5029072"},{"id":"197d553a-3042-4f78-adc0-7fec64e18eb7"}],"width":300,"min_width":300,"margin":[5,10],"align":"start","title":"Band","options":["u","g","r","i","z","i"],"value":"u"}}]}},{"type":"object","name":"panel.models.layout.Column","id":"959db6a4-a6cf-43d6-8e0e-746c364d62de","attributes":{"name":"Column01703","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"363f04bd-4d82-4e3c-8ea8-433e1c74c150"},{"id":"515910ba-744a-49a3-97e8-58e45ab5e6a8"},{"id":"1bca7df4-b270-4965-a20a-0ea6e5029072"},{"id":"197d553a-3042-4f78-adc0-7fec64e18eb7"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.markup.HTML","id":"b4be70c5-6b74-4eb7-abc7-5686591d3e4e","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto ...

# %%
# Create a selector for choosing psdMags or psfFluxes
units_selector = pn.widgets.Select(name='Flux/Mag', options=['psfFlux','psfMag'])

# %%
data = rdf[(rdf['psfMag'] < mag_slider) & (rdf['band'] == band_selector)]
plot = data.hvplot.scatter(x='expMidptMJD',y=units_selector, title=band_selector, color=color).opts(width=500,height=300)
plot
# Out:
# <div id='c7839b27-c2d7-46e9-bccd-48c6172fced1'>
#   <div id="d42544d8-5621-4197-b002-e54765eff1f7" data-root-id="c7839b27-c2d7-46e9-bccd-48c6172fced1" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"28e10c5b-5760-45f8-bed7-c9da8e8cd7ec":{"version":"3.4.3","title":"Bokeh Application","roots":[{"type":"object","name":"Row","id":"c7839b27-c2d7-46e9-bccd-48c6172fced1","attributes":{"name":"Row01808","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"type":"object","name":"ImportedStyleSheet","id":"eb624d43-df7f-4905-bddc-945372878538","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/loading.css"}},{"type":"object","name":"ImportedStyleSheet","id":"7d3f287e-4a33-49fd-9796-7dc59a334a3d","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/listpanel.css"}},{"type":"object","name":"ImportedStyleSheet","id":"4646b896-1688-49f5-8da2-bacfd9203199","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/default.css"}},{"type":"object","name":"ImportedStyleSheet","id":"bb8db1ba-c516-4f99-aa99-36a05f7edeba","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/bundled/theme/native.css"}}],"margin":0,"align":"start","children":[{"type":"object","name":"Row","id":"d088ce72-0798-4107-9c24-c1e8778ff480","attributes":{"name":"Row01843","stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"eb624d43-df7f-4905-bddc-945372878538"},{"id":"7d3f287e-4a33-49fd-9796-7dc59a334a3d"},{"id":"4646b896-1688-49f5-8da2-bacfd9203199"},{"id":"bb8db1ba-c516-4f99-aa99-36a05f7edeba"}],"margin":0,"align":"start","children":[{"type":"object","name":"panel.models.layout.Column","id":"9a0c719c-468c-4d82-bdbc-21b9e83569cd","attributes":{"name":"WidgetBox01842","css_classes":["panel-widget-box"],"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"eb624d43-df7f-4905-bddc-945372878538"},{"type":"object","name":"ImportedStyleSheet","id":"a727d6b3-b4a0-42ad-bcec-951e991336ad","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/widgetbox.css"}},{"id":"7d3f287e-4a33-49fd-9796-7dc59a334a3d"},{"id":"4646b896-1688-49f5-8da2-bacfd9203199"},{"id":"bb8db1ba-c516-4f99-aa99-36a05f7edeba"}],"margin":0,"align":"start","children":[{"type":"object","name":"Slider","id":"5a255711-370f-498e-80e2-4acce13fb8f9","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"eb624d43-df7f-4905-bddc-945372878538"},{"id":"4646b896-1688-49f5-8da2-bacfd9203199"},{"id":"bb8db1ba-c516-4f99-aa99-36a05f7edeba"}],"margin":[5,10],"align":"start","title":"Max magnitude","start":15,"end":32,"value":26.7,"step":0.05}},{"type":"object","name":"panel.models.widgets.CustomSelect","id":"328cee68-4c37-4f2d-b7a0-6c06883b8714","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 400px));\n}",{"id":"eb624d43-df7f-4905-bddc-945372878538"},{"type":"object","name":"ImportedStyleSheet","id":"ee6bae83-2d65-4969-b1f8-b39f60701587","attributes":{"url":"https://cdn.holoviz.org/panel/1.4.5/dist/css/select.css"}},{"id":"4646b896-1688-49f5-8da2-bacfd9203199"},{"id":"bb8db1ba-c516-4f99-aa99-36a05f7edeba"}],"width":300,"min_width":300,"margin":[5,10],"align":"start","title":"Band","options":["u","g","r","i","z","i"],"value":"u"}},{"type":"object","name":"panel.models.widgets.CustomSelect","id":"77009e84-1389-409e-938a-f956d372d08c","attributes":{"stylesheets":["\n:host(.pn-loading):before, .pn-loading:before {\n  background-color: #c3c3c3;\n  mask-size: auto calc(min(50%, 400px));\n  -webkit-mask-size: auto calc(min(50%, 40 ...
